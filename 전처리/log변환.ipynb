# %%
# matplotlib
import matplotlib as mpl
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm

plt.rcParams['axes.unicode_minus'] = False  # matplotlib 마이너스기호 표시
plt.rc('font', family='NanumGothic')  # matplotlib 한글폰트 표시

# pandas
import pandas as pd

# %%
data = pd.read_csv('/content/final_clusters.csv',encoding='cp949')
data
# Out:
#     Unnamed: 0   자치구   노인인구수  역개수  무료급식소개수  시설개수
# 0            0   종로구   27704   15        5     8
# 1            1    중구   24660   23        2    11
# 2            2   용산구   38478   10        3     7
# 3            3   성동구   47530   14        5    19
# 4            4   광진구   53737   11        2    22
# 5            5  동대문구   64255    6        2    35
# 6            6   중랑구   74790    8       11    48
# 7            7   성북구   77293    9       11    28
# 8            8   강북구   66170    3       11    35
# 9            9   도봉구   66942    3        0    29
# 10          10   노원구   91946   13        3    46
# 11          11   은평구   89422   13       10    41
# 12          12  서대문구   55502    5        8    23
# 13          13   마포구   55533   16       11    29
# 14          14   양천구   72235    5       10    35
# 15          15   강서구   96880    9       14    40
# 16          16   구로구   74491    7        6    25
# 17          17   금천구   42226    1        7    18
# ...

# %%
# draw histogram graph
data.hist(bins=20, figsize=(10,10))
# Out:
# array([[<Axes: title={'center': 'Unnamed: 0'}>,
#         <Axes: title={'center': '노인인구수'}>],
#        [<Axes: title={'center': '역개수'}>,
#         <Axes: title={'center': '무료급식소개수'}>],
#        [<Axes: title={'center': '시설개수'}>, <Axes: >]], dtype=object)
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# ...

# %%
col = [c for c in data.columns if data[c].dtype != 'object']
num_df = data[col]
num_df
# Out:
#     Unnamed: 0   노인인구수  역개수  무료급식소개수  시설개수
# 0            0   27704   15        5     8
# 1            1   24660   23        2    11
# 2            2   38478   10        3     7
# 3            3   47530   14        5    19
# 4            4   53737   11        2    22
# 5            5   64255    6        2    35
# 6            6   74790    8       11    48
# 7            7   77293    9       11    28
# 8            8   66170    3       11    35
# 9            9   66942    3        0    29
# 10          10   91946   13        3    46
# 11          11   89422   13       10    41
# 12          12   55502    5        8    23
# 13          13   55533   16       11    29
# 14          14   72235    5       10    35
# 15          15   96880    9       14    40
# 16          16   74491    7        6    25
# 17          17   42226    1        7    18
# 18          18   63349   11        5    22
# 19          19   67872   12        9    29
# 20          20   81848    4        6    29
# ...

# %%
num_df = num_df.drop('Unnamed: 0')
num_df
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-11-3801312c51d4> in <cell line: 1>()
# ----> 1 num_df = num_df.drop(['Unnamed: 0'])
#       2 num_df
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
#     333         # error: "Callable[[VarArg(Any), KwArg(Any)], Any]" has no
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    5397                 weight  1.0     0.8
#    5398         """
# -> 5399         return super().drop(
#    5400             labels=labels,
#    5401             axis=axis,
#
# ...

# %%
import numpy as np
log_df = np.log(num_df)
log_df
# Out:
# /usr/local/lib/python3.10/dist-packages/pandas/core/internals/blocks.py:351: RuntimeWarning: divide by zero encountered in log
#   result = func(self.values, **kwargs)
#     Unnamed: 0      노인인구수       역개수   무료급식소개수      시설개수
# 0         -inf  10.229332  2.708050  1.609438  2.079442
# 1     0.000000  10.112938  3.135494  0.693147  2.397895
# 2     0.693147  10.557842  2.302585  1.098612  1.945910
# 3     1.098612  10.769116  2.639057  1.609438  2.944439
# 4     1.386294  10.891857  2.397895  0.693147  3.091042
# 5     1.609438  11.070615  1.791759  0.693147  3.555348
# 6     1.791759  11.222439  2.079442  2.397895  3.871201
# 7     1.945910  11.255359  2.197225  2.397895  3.332205
# 8     2.079442  11.099982  1.098612  2.397895  3.555348
# 9     2.197225  11.111582  1.098612      -inf  3.367296
# 10    2.302585  11.428957  2.564949  1.098612  3.828641
# 11    2.397895  11.401122  2.564949  2.302585  3.713572
# 12    2.484907  10.924174  1.609438  2.079442  3.135494
# ...

# %%
import statsmodels.api as sm
data['intercept']=1
model = sm.OLS(data['무료급식소개수'],data[['노인인구수','역개수','시설개수']])
results = model.fit()
print(results.summary())
# Out:
#                                  OLS Regression Results
# ...
# Dep. Variable:                무료급식소개수   R-squared (uncentered):                   0.756
# Model:                            OLS   Adj. R-squared (uncentered):              0.722
# Method:                 Least Squares   F-statistic:                              22.69
# Date:                Sat, 14 Oct 2023   Prob (F-statistic):                    6.30e-07
# Time:                        02:36:05   Log-Likelihood:                         -68.296
# No. Observations:                  25   AIC:                                      142.6
# Df Residuals:                      22   BIC:                                      146.2
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ...

# %%
노인인구수	역개수	무료급식소개수	시설개수

# %%
import pandas as pd
import statsmodels.api as sm
statsmodels.stats.outliers_influence.variance_inflation_factor(exog, exog_idx)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-17-2db687c3caa1> in <cell line: 3>()
#       1 import pandas as pd
#       2 import statsmodels.api as sm
# ----> 3 statsmodels.stats.outliers_influence.variance_inflation_factor(exog, exog_idx)
#
# NameError: name 'statsmodels' is not defined

# %%
# !pip install statsmodels.stats
# Out:
# ERROR: Could not find a version that satisfies the requirement statsmodels.stats (from versions: none)
# ERROR: No matching distribution found for statsmodels.stats

# %%
X_train = data[['노인인구수','역개수','무료급식소개수','시설개수']]

# %%
def feature_engineering_XbyVIF( ):
  vif = pd.DataFrame()
  vif['VIF_Factor'] = [variance_inflation_factor(X_train.values,i) for i in range(X_train.shape[1])]
  vif['Feature'] = X_train.columns
  return vif

# %%
vif = feature_engineering_XbyVIF(X_train)
print(vif)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-20-7e0ec7c99748> in <cell line: 1>()
# ----> 1 vif = feature_engineering_XbyVIF(X_train)
#       2 print(vif)
#
# TypeError: feature_engineering_XbyVIF() takes 0 positional arguments but 1 was given
