# %%
import pandas as pd
import matplotlib.pyplot as plt 
import seaborn as sns
import folium
import json
import numpy as np

# %%
data = pd.read_csv('final_clusters.csv')
data.drop('Unnamed: 0', axis=1, inplace=True)

# %%
nbls = pd.read_csv('국민기초생활보장+수급자_20231003171616.csv')
nbls = nbls.loc[:,['동별(2)','동별(3)','2021.2']]
nbls.rename(columns={'동별(2)':'자치구', '동별(3)':'행정동','2021.2':'인원'}, inplace=True)
nbls.drop([0,1,2,3], axis=0, inplace=True)
nbls.reset_index(drop=True,inplace=True)

# %%
for i in range(len(nbls)):
    if nbls.loc[i,'행정동'] in ['소계','기타']:
        nbls.drop(i,axis=0,inplace=True)
nbls.reset_index(drop=True,inplace=True)

# %%
nbls
# Out:
#      자치구   행정동    인원
# 0    종로구   사직동   125
# 1    종로구   삼청동    45
# 2    종로구   부암동   174
# 3    종로구   평창동   144
# 4    종로구   무악동   206
# ..   ...   ...   ...
# 421  강동구  암사1동  1922
# 422  강동구  천호2동  2002
# 423  강동구    길동  1637
# 424  강동구  상일1동   396
# 425  강동구  상일2동   689
#
# [426 rows x 3 columns]

# %%
group1 = ['동대문구','중랑구','성북구','강북구','도봉구','노원구', '은평구', '서대문구', '마포구','양천구','강서구','구로구','금천구',
         '영등포구','동작구','관악구','강동구']
group2 = ['종로구','중구','용산구','성동구','광진구']
group3 = ['서초구','강남구','송파구']

# %%
data1 = [{'행정동':0,'기초생활수급자인원':0}]
data1 = pd.DataFrame(data1)
data2 = [{'행정동':0,'기초생활수급자인원':0}]
data2 = pd.DataFrame(data2)
data3 = [{'행정동':0,'기초생활수급자인원':0}]
data3 = pd.DataFrame(data3)

# %%
for i in range(len(nbls)):
    if nbls.loc[i,'자치구'] in group1:
        data1.loc[i,'행정동'] = nbls.loc[i,'행정동']
        data1.loc[i,'기초생활수급자인원'] = nbls.loc[i,'인원'] #279행
data1.drop(0, axis=0, inplace=True)
data1.reset_index(drop=True,inplace=True)
data1
# Out:
# C:\Users\hi\AppData\Local\Temp\ipykernel_10644\3949123395.py:3: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '회기동' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   data1.loc[i,'행정동'] = nbls.loc[i,'행정동']
# C:\Users\hi\AppData\Local\Temp\ipykernel_10644\3949123395.py:4: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '364' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   data1.loc[i,'기초생활수급자인원'] = nbls.loc[i,'인원'] #279행
#         행정동 기초생활수급자인원
# 0       회기동       364
# 1      휘경1동       386
# 2      휘경2동       703
# 3      청량리동      1741
# 4       용신동      1680
# 5       제기동      1577
# 6      전농1동      1837
# 7      전농2동       805
# 8     답십리2동      1313
# 9      장안1동      1620
# 10     장안2동      1366
# 11     이문1동       743
# 12     이문2동      1009
# ...

# %%
for i in range(len(nbls)):
    if nbls.loc[i,'자치구'] in group2:
        data2.loc[i,'행정동'] = nbls.loc[i,'행정동']
        data2.loc[i,'기초생활수급자인원'] = nbls.loc[i,'인원'] #80행
data2
# Out:
# C:\Users\hi\AppData\Local\Temp\ipykernel_10644\239555392.py:3: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '사직동' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   data2.loc[i,'행정동'] = nbls.loc[i,'행정동']
# C:\Users\hi\AppData\Local\Temp\ipykernel_10644\239555392.py:4: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '125' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   data2.loc[i,'기초생활수급자인원'] = nbls.loc[i,'인원'] #80행
#             행정동 기초생활수급자인원
# 0           사직동       125
# 1           삼청동        45
# 2           부암동       174
# 3           평창동       144
# 4           무악동       206
# 5           교남동       215
# 6           가회동        77
# 7   종로1.2.3.4가동       786
# 8       종로5.6가동       319
# 9           이화동       288
# 10         창신1동       501
# ...

# %%
for i in range(len(nbls)):
    if nbls.loc[i,'자치구'] in group3:
        data3.loc[i,'행정동'] = nbls.loc[i,'행정동']
        data3.loc[i,'기초생활수급자인원'] = nbls.loc[i,'인원'] #67행
data3.drop(0, axis=0, inplace=True)
data3.reset_index(drop=True,inplace=True)
data3
# Out:
# C:\Users\hi\AppData\Local\Temp\ipykernel_10644\2328134489.py:3: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '서초1동' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   data3.loc[i,'행정동'] = nbls.loc[i,'행정동']
# C:\Users\hi\AppData\Local\Temp\ipykernel_10644\2328134489.py:4: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '356' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   data3.loc[i,'기초생활수급자인원'] = nbls.loc[i,'인원'] #67행
#      행정동 기초생활수급자인원
# 0   서초1동       356
# 1   서초2동       157
# 2   서초3동       359
# 3   서초4동        70
# 4    잠원동       254
# 5   반포본동        10
# 6   반포1동       458
# 7   반포2동         7
# 8   반포3동        41
# 9   반포4동       117
# 10  방배본동       361
# 11  방배1동       320
# 12  방배2동       493
# 13  방배3동       137
# 14  방배4동       335
# ...

# %%
부양비 = pd.read_csv('부양비+및+노령화지수_20231003180139.csv')
부양비 = 부양비.loc[:,['동별(1)','동별(2)','2022.1']]
부양비.rename(columns={'동별(1)':'자치구','동별(2)':'행정동','2022.1':'노년부양비'}, inplace=True)
부양비.drop([0,1], axis=0, inplace=True)
부양비.reset_index(drop=True,inplace=True)

# %%
부양비
# Out:
#      자치구   행정동 노년부양비
# 0    종로구    소계  24.8
# 1    종로구   사직동  27.1
# 2    종로구   삼청동  35.1
# 3    종로구   부암동  26.2
# 4    종로구   평창동  27.8
# ..   ...   ...   ...
# 446  강동구  암사1동  25.3
# 447  강동구  천호2동  24.3
# 448  강동구    길동  25.4
# 449  강동구  상일1동  18.0
# 450  강동구  상일2동  23.3
#
# [451 rows x 3 columns]

# %%
for i in range(len(부양비)):
    if 부양비.loc[i,'행정동'] in ['소계','기타']:
        부양비.drop(i,axis=0,inplace=True)
부양비.reset_index(drop=True,inplace=True)

# %%
부양비1 = [{'행정동':0,'노년부양비':0}]
부양비1 = pd.DataFrame(부양비1)
부양비2 = [{'행정동':0,'노년부양비':0}]
부양비2 = pd.DataFrame(부양비2)
부양비3 = [{'행정동':0,'노년부양비':0}]
부양비3 = pd.DataFrame(부양비3)

# %%
for i in range(len(부양비)):
    if 부양비.loc[i,'자치구'] in group1:
        부양비1.loc[i,'행정동'] = 부양비.loc[i,'행정동']
        부양비1.loc[i,'노년부양비'] = 부양비.loc[i,'노년부양비'] #279행
부양비1.drop(0, axis=0, inplace=True)
부양비1.reset_index(drop=True,inplace=True)
부양비1
# Out:
# C:\Users\hi\AppData\Local\Temp\ipykernel_10644\1360696221.py:3: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '회기동' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   부양비1.loc[i,'행정동'] = 부양비.loc[i,'행정동']
# C:\Users\hi\AppData\Local\Temp\ipykernel_10644\1360696221.py:4: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '13.8' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   부양비1.loc[i,'노년부양비'] = 부양비.loc[i,'노년부양비'] #279행
#       행정동 노년부양비
# 0     회기동  13.8
# 1    휘경1동  16.6
# 2    휘경2동  22.1
# 3    청량리동  43.8
# 4     용신동  22.3
# ..    ...   ...
# 274  암사1동  25.3
# 275  천호2동  24.3
# 276    길동  25.4
# 277  상일1동  18.0
# 278  상일2동  23.3
#
# [279 rows x 2 columns]

# %%
for i in range(len(부양비)):
    if 부양비.loc[i,'자치구'] in group2:
        부양비2.loc[i,'행정동'] = 부양비.loc[i,'행정동']
        부양비2.loc[i,'노년부양비'] = 부양비.loc[i,'노년부양비'] #80행
부양비2.reset_index(drop=True,inplace=True)
부양비2
# Out:
# C:\Users\hi\AppData\Local\Temp\ipykernel_10644\1270508634.py:3: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '사직동' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   부양비2.loc[i,'행정동'] = 부양비.loc[i,'행정동']
# C:\Users\hi\AppData\Local\Temp\ipykernel_10644\1270508634.py:4: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '27.1' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   부양비2.loc[i,'노년부양비'] = 부양비.loc[i,'노년부양비'] #80행
#      행정동 노년부양비
# 0    사직동  27.1
# 1    삼청동  35.1
# 2    부암동  26.2
# 3    평창동  27.8
# 4    무악동  26.7
# ..   ...   ...
# 75   광장동  16.1
# 76  자양1동  20.8
# 77  자양2동  23.6
# 78  자양3동  22.4
# 79  자양4동  23.9
#
# [80 rows x 2 columns]

# %%
for i in range(len(부양비)):
    if 부양비.loc[i,'자치구'] in group3:
        부양비3.loc[i,'행정동'] = 부양비.loc[i,'행정동']
        부양비3.loc[i,'노년부양비'] = 부양비.loc[i,'노년부양비'] #67행
부양비3.drop(0, axis=0, inplace=True)
부양비3.reset_index(drop=True,inplace=True)
부양비3
# Out:
# C:\Users\hi\AppData\Local\Temp\ipykernel_10644\1735778400.py:3: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '서초1동' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   부양비3.loc[i,'행정동'] = 부양비.loc[i,'행정동']
# C:\Users\hi\AppData\Local\Temp\ipykernel_10644\1735778400.py:4: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '20.5' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   부양비3.loc[i,'노년부양비'] = 부양비.loc[i,'노년부양비'] #67행
#      행정동 노년부양비
# 0   서초1동  20.5
# 1   서초2동  17.1
# 2   서초3동  20.4
# 3   서초4동  20.4
# 4    잠원동  17.4
# ..   ...   ...
# 62  잠실4동  35.7
# 63  잠실6동  16.1
# 64  잠실7동  26.2
# 65  잠실2동  21.7
# 66  잠실3동  11.7
#
# [67 rows x 2 columns]

# %%
data1 = pd.merge(data1,부양비1, on='행정동')
data1
# Out:
#         행정동 기초생활수급자인원 노년부양비
# 0       회기동       364  13.8
# 1      휘경1동       386  16.6
# 2      휘경2동       703  22.1
# 3      청량리동      1741  43.8
# 4       용신동      1680  22.3
# 5       제기동      1577  30.6
# 6      전농1동      1837  27.8
# 7      전농2동       805  29.5
# 8     답십리2동      1313  24.0
# 9      장안1동      1620  23.4
# 10     장안2동      1366  19.0
# 11     이문1동       743  29.2
# 12     이문2동      1009  20.0
# 13    답십리1동       866  29.3
# 14     면목2동      1715  27.1
# 15     면목4동      1807  29.5
# 16     면목5동       813  22.3
# 17     면목7동      1137  28.5
# 18     상봉1동      1714  23.2
# 19     상봉2동      1103  18.7
# 20     중화1동      1105  27.7
# 21     중화2동      2511  28.3
# 22      묵1동      1265  24.7
# 23      묵2동      1100  27.9
# 24     망우3동      1921  29.9
# 25     신내1동      2097  27.2
# 26     신내2동      1440  30.7
# 27     면목본동      2540  25.0
# 28   면목3.8동      1970  28.9
# 29     망우본동      2343  26.7
# 30     돈암1동       621  29.1
# 31     돈암2동       372  21.6
# ...

# %%
data2 = pd.merge(data2,부양비2, on='행정동')
data2
# Out:
#      행정동 기초생활수급자인원 노년부양비
# 0    사직동       125  27.1
# 1    삼청동        45  35.1
# 2    부암동       174  26.2
# 3    평창동       144  27.8
# 4    무악동       206  26.7
# ..   ...       ...   ...
# 75   광장동       271  16.1
# 76  자양1동      1294  20.8
# 77  자양2동       883  23.6
# 78  자양3동       381  22.4
# 79  자양4동      1001  23.9
#
# [80 rows x 3 columns]

# %%
data3 = pd.merge(data3,부양비3, on='행정동')
data3
# Out:
#      행정동 기초생활수급자인원 노년부양비
# 0   서초1동       356  20.5
# 1   서초2동       157  17.1
# 2   서초3동       359  20.4
# 3   서초4동        70  20.4
# 4    잠원동       254  17.4
# 5   반포본동        10  20.1
# 6   반포1동       458  16.6
# 7   반포2동         7  20.1
# 8   반포3동        41  20.3
# 9   반포4동       117  21.9
# 10  방배본동       361  21.5
# 11  방배1동       320  24.5
# 12  방배2동       493  26.8
# 13  방배3동       137  27.4
# 14  방배4동       335  21.1
# 15  양재1동      2293  24.3
# 16  양재2동       678  18.4
# 17   내곡동       815  30.0
# 18   신사동       246  27.4
# 19  논현1동       868  16.5
# 20  논현2동       489  19.8
# 21  삼성1동       168  24.0
# 22  삼성2동       466  16.9
# 23  대치1동        17  15.9
# 24  대치4동       657  13.1
# 25  역삼1동      1075  12.2
# 26  역삼2동       570  14.0
# 27  도곡1동       157  20.4
# 28  도곡2동        82  22.5
# 29  개포1동       162  37.6
# 30  개포4동       713  20.0
# 31  일원본동       125  21.1
# 32  일원1동      1696  32.3
# 33   수서동      3377  56.9
# 34   세곡동      2342  22.8
# 35  압구정동       152  30.5
# ...

# %%
독거노인 = pd.read_csv('독거노인_현황.csv')
독거노인
독거노인 = 독거노인.loc[:,['동별(2)','동별(3)','2022.3','2022.6']]
독거노인.rename(columns={'동별(2)':'자치구','동별(3)':'행정동','2022.3':'기초생활수급자','2022.6':'저소득노인'}, inplace=True)
독거노인.drop([0,1,2,3], axis=0, inplace=True)
독거노인.reset_index(drop=True,inplace=True)

# %%
독거노인
# Out:
#       자치구          행정동  독거노인
# 0     종로구          사직동    66
# 1     종로구          삼청동    23
# 2     종로구          부암동    74
# 3     종로구          평창동    78
# 4     종로구          무악동   108
# 5     종로구          교남동    73
# 6     종로구          가회동    27
# 7     종로구  종로1.2.3.4가동   423
# 8     종로구      종로5.6가동   156
# 9     종로구          이화동   140
# 10    종로구         창신1동   216
# 11    종로구         창신2동   243
# 12    종로구         창신3동    84
# 13    종로구         숭인1동   141
# 14    종로구         숭인2동   255
# 15    종로구        청운효자동    95
# 16    종로구          혜화동   147
# 17     중구          소공동    17
# 18     중구          회현동   221
# 19     중구           명동    32
# 20     중구           필동    61
# 21     중구          장충동    63
# 22     중구          광희동   123
# 23     중구         을지로동    98
# 24     중구         신당5동   232
# 25     중구          황학동   234
# 26     중구          중림동   254
# 27     중구          신당동   215
# 28     중구          다산동   233
# 29     중구          약수동   528
# 30     중구          청구동   365
# ...

# %%
독거노인.loc[122,'행정동'] = '정릉1동'
독거노인.loc[123,'행정동'] = '정릉2동'
독거노인.loc[124,'행정동'] = '정릉3동'
독거노인.loc[125,'행정동'] = '정릉4동'

# %%
for i in range(len(독거노인)):
    if 독거노인.loc[i,'자치구'] == '동대문':
        독거노인.loc[i,'자치구'] = '동대문구'

# %%
독거노인['기초생활수급자'] = 독거노인['기초생활수급자'].replace('-', 0)
독거노인['저소득노인'] = 독거노인['저소득노인'].replace('-', 0)

# %%
독거노인['기초생활수급자'] = 독거노인['기초생활수급자'].astype(int)
독거노인['저소득노인'] = 독거노인['저소득노인'].astype(int)

# %%
for i in range(len(독거노인)):
    독거노인.loc[i,'독거노인'] = 독거노인.loc[i,'기초생활수급자'] + 독거노인.loc[i,'저소득노인']
독거노인['독거노인'] = 독거노인['독거노인'].astype(int)
독거노인
# Out:
#       자치구          행정동  기초생활수급자  저소득노인   독거노인
# 0     종로구           소계     2000    349   2349
# 1     종로구          사직동       56     10     66
# 2     종로구          삼청동       19      4     23
# 3     종로구          부암동       58     16     74
# 4     종로구          평창동       56     22     78
# 5     종로구          무악동       88     20    108
# 6     종로구          교남동       55     18     73
# 7     종로구          가회동       19      8     27
# 8     종로구  종로1.2.3.4가동      404     19    423
# 9     종로구      종로5.6가동      124     32    156
# 10    종로구          이화동      100     40    140
# 11    종로구         창신1동      201     15    216
# 12    종로구         창신2동      209     34    243
# 13    종로구         창신3동       77      7     84
# 14    종로구         숭인1동      116     25    141
# 15    종로구         숭인2동      218     37    255
# 16    종로구        청운효자동       72     23     95
# 17    종로구          혜화동      128     19    147
# 18     중구           소계     2392    366   2758
# ...

# %%
독거노인.drop(['기초생활수급자','저소득노인'], axis=1, inplace=True)

# %%
for i in range(len(독거노인)):
    if 독거노인.loc[i,'행정동'] in ['소계','기타']:
        독거노인.drop(i,axis=0,inplace=True)
독거노인.reset_index(drop=True,inplace=True)

# %%
독거노인1 = [{'행정동':0,'독거노인수':0}]
독거노인1 = pd.DataFrame(독거노인1)
독거노인2 = [{'행정동':0,'독거노인수':0}]
독거노인2 = pd.DataFrame(독거노인2)
독거노인3 = [{'행정동':0,'독거노인수':0}]
독거노인3 = pd.DataFrame(독거노인3)

# %%
for i in range(len(독거노인)):
    if 독거노인.loc[i,'자치구'] in group1:
        독거노인1.loc[i,'행정동'] = 독거노인.loc[i,'행정동']
        독거노인1.loc[i,'독거노인수'] = 독거노인.loc[i,'독거노인'] #279행
독거노인1.drop(0, axis=0, inplace=True)
독거노인1.reset_index(drop=True,inplace=True)
독거노인1
# Out:
# C:\Users\hi\AppData\Local\Temp\ipykernel_10644\824415175.py:3: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '회기동' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   독거노인1.loc[i,'행정동'] = 독거노인.loc[i,'행정동']
#         행정동   독거노인수
# 0       회기동    99.0
# 1      휘경1동   128.0
# 2      휘경2동   215.0
# 3      청량리동   915.0
# 4       용신동   761.0
# 5       제기동   772.0
# 6      전농1동   807.0
# 7      전농2동   330.0
# 8     답십리2동   566.0
# 9      장안1동   481.0
# 10     장안2동   370.0
# 11     이문1동   277.0
# 12     이문2동   401.0
# 13    답십리1동   326.0
# 14     면목2동   550.0
# 15     면목4동   557.0
# 16     면목5동   194.0
# 17     면목7동   377.0
# 18     상봉1동   463.0
# 19     상봉2동   328.0
# 20     중화1동   305.0
# 21     중화2동   788.0
# 22      묵1동   365.0
# 23      묵2동   350.0
# 24     망우3동   552.0
# 25     신내1동   570.0
# 26     신내2동   521.0
# 27     면목본동   835.0
# 28   면목3.8동   600.0
# ...

# %%
len(독거노인['행정동'].unique())
# Out:
# 425

# %%
for i in range(len(독거노인)):
    if 독거노인.loc[i,'자치구'] in group2:
        독거노인2.loc[i,'행정동'] = 독거노인.loc[i,'행정동']
        독거노인2.loc[i,'독거노인수'] = 독거노인.loc[i,'독거노인'] #80행
독거노인2.reset_index(drop=True,inplace=True)
독거노인2
# Out:
# C:\Users\hi\AppData\Local\Temp\ipykernel_10644\853381733.py:3: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '사직동' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   독거노인2.loc[i,'행정동'] = 독거노인.loc[i,'행정동']
#             행정동  독거노인수
# 0           사직동   66.0
# 1           삼청동   23.0
# 2           부암동   74.0
# 3           평창동   78.0
# 4           무악동  108.0
# 5           교남동   73.0
# 6           가회동   27.0
# 7   종로1.2.3.4가동  423.0
# 8       종로5.6가동  156.0
# 9           이화동  140.0
# 10         창신1동  216.0
# 11         창신2동  243.0
# 12         창신3동   84.0
# 13         숭인1동  141.0
# 14         숭인2동  255.0
# 15        청운효자동   95.0
# 16          혜화동  147.0
# 17          소공동   17.0
# 18          회현동  221.0
# 19           명동   32.0
# 20           필동   61.0
# 21          장충동   63.0
# 22          광희동  123.0
# 23         을지로동   98.0
# 24         신당5동  232.0
# 25          황학동  234.0
# ...

# %%
for i in range(len(독거노인)):
    if 독거노인.loc[i,'자치구'] in group3:
        독거노인3.loc[i,'행정동'] = 독거노인.loc[i,'행정동']
        독거노인3.loc[i,'독거노인수'] = 독거노인.loc[i,'독거노인'] #67행
독거노인3.drop(0, axis=0, inplace=True)
독거노인3.reset_index(drop=True,inplace=True)
독거노인3
# Out:
# C:\Users\hi\AppData\Local\Temp\ipykernel_10644\1101051082.py:3: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '서초1동' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   독거노인3.loc[i,'행정동'] = 독거노인.loc[i,'행정동']
#      행정동   독거노인수
# 0   서초1동   143.0
# 1   서초2동    68.0
# 2   서초3동   121.0
# 3   서초4동    30.0
# 4    잠원동   116.0
# 5   반포본동     0.0
# 6   반포1동   141.0
# 7   반포2동     5.0
# 8   반포3동    16.0
# 9   반포4동    37.0
# 10  방배본동    92.0
# 11  방배1동   137.0
# 12  방배2동   249.0
# 13  방배3동    53.0
# 14  방배4동   132.0
# 15  양재1동   712.0
# 16  양재2동   284.0
# 17   내곡동   200.0
# 18   신사동    66.0
# 19  개포3동   453.0
# 20  논현1동   157.0
# 21  논현2동    83.0
# 22  삼성1동    24.0
# 23  삼성2동   109.0
# 24  대치1동     4.0
# 25  대치4동   112.0
# 26  역삼1동   205.0
# 27  역삼2동    87.0
# 28  도곡1동    40.0
# 29  도곡2동    18.0
# 30  개포1동    72.0
# 31  개포4동   157.0
# 32  일원본동    26.0
# 33  일원1동   447.0
# ...

# %%
data1 = pd.merge(data1,독거노인1, on='행정동', how='outer')
data1
# Out:
#         행정동 기초생활수급자인원 노년부양비   독거노인수
# 0       회기동       364  13.8    99.0
# 1      휘경1동       386  16.6   128.0
# 2      휘경2동       703  22.1   215.0
# 3      청량리동      1741  43.8   915.0
# 4       용신동      1680  22.3   761.0
# 5       제기동      1577  30.6   772.0
# 6      전농1동      1837  27.8   807.0
# 7      전농2동       805  29.5   330.0
# 8     답십리2동      1313  24.0   566.0
# 9      장안1동      1620  23.4   481.0
# 10     장안2동      1366  19.0   370.0
# 11     이문1동       743  29.2   277.0
# 12     이문2동      1009  20.0   401.0
# 13    답십리1동       866  29.3   326.0
# 14     면목2동      1715  27.1   550.0
# 15     면목4동      1807  29.5   557.0
# 16     면목5동       813  22.3   194.0
# 17     면목7동      1137  28.5   377.0
# 18     상봉1동      1714  23.2   463.0
# 19     상봉2동      1103  18.7   328.0
# 20     중화1동      1105  27.7   305.0
# 21     중화2동      2511  28.3   788.0
# 22      묵1동      1265  24.7   365.0
# 23      묵2동      1100  27.9   350.0
# 24     망우3동      1921  29.9   552.0
# ...

# %%
data2 = pd.merge(data2,독거노인2, on='행정동', how='outer')
data2
# Out:
#             행정동 기초생활수급자인원  독거노인수
# 0           사직동       125   66.0
# 1           삼청동        45   23.0
# 2           부암동       174   74.0
# 3           평창동       144   78.0
# 4           무악동       206  108.0
# 5           교남동       215   73.0
# 6           가회동        77   27.0
# 7   종로1.2.3.4가동       786  423.0
# 8       종로5.6가동       319  156.0
# 9           이화동       288  140.0
# 10         창신1동       501  216.0
# 11         창신2동       491  243.0
# 12         창신3동       247   84.0
# 13         숭인1동       296  141.0
# 14         숭인2동       475  255.0
# 15        청운효자동       229   95.0
# 16          혜화동       380  147.0
# 17          소공동        49   17.0
# 18          회현동       463  221.0
# 19           명동        93   32.0
# 20           필동       103   61.0
# 21          장충동       157   63.0
# 22          광희동       232  123.0
# 23         을지로동       148   98.0
# 24         신당5동       511  232.0
# 25          황학동       536  234.0
# 26          중림동       622  254.0
# ...

# %%
data3 = pd.merge(data3,독거노인3, on='행정동', how='outer')
data3
# Out:
#      행정동 기초생활수급자인원 노년부양비   독거노인수
# 0   서초1동       356  20.5   143.0
# 1   서초2동       157  17.1    68.0
# 2   서초3동       359  20.4   121.0
# 3   서초4동        70  20.4    30.0
# 4    잠원동       254  17.4   116.0
# 5   반포본동        10  20.1     0.0
# 6   반포1동       458  16.6   141.0
# 7   반포2동         7  20.1     5.0
# 8   반포3동        41  20.3    16.0
# 9   반포4동       117  21.9    37.0
# 10  방배본동       361  21.5    92.0
# 11  방배1동       320  24.5   137.0
# 12  방배2동       493  26.8   249.0
# 13  방배3동       137  27.4    53.0
# 14  방배4동       335  21.1   132.0
# 15  양재1동      2293  24.3   712.0
# 16  양재2동       678  18.4   284.0
# 17   내곡동       815  30.0   200.0
# 18   신사동       246  27.4    66.0
# 19  논현1동       868  16.5   157.0
# 20  논현2동       489  19.8    83.0
# 21  삼성1동       168  24.0    24.0
# 22  삼성2동       466  16.9   109.0
# 23  대치1동        17  15.9     4.0
# 24  대치4동       657  13.1   112.0
# 25  역삼1동      1075  12.2   205.0
# 26  역삼2동       570  14.0    87.0
# ...

# %%
고령자 = pd.read_csv('고령자현황_동까지.csv')
고령자 = 고령자수.loc[:,['동별(2)','동별(3)','2022.6']]
고령자.rename(columns={'동별(2)':'자치구','동별(3)':'행정동','2022.6':'고령자수'}, inplace=True)
고령자.drop([0,1,2], axis=0, inplace=True)
고령자.reset_index(drop=True,inplace=True)

# %%
for i in range(len(고령자)):
    if 고령자.loc[i,'행정동'] in ['소계','기타']:
        고령자.drop(i,axis=0,inplace=True)
고령자.reset_index(drop=True,inplace=True)

# %%
고령자1 = [{'행정동':0,'고령자수':0}]
고령자1 = pd.DataFrame(고령자1)
고령자2 = [{'행정동':0,'고령자수':0}]
고령자2 = pd.DataFrame(고령자2)
고령자3 = [{'행정동':0,'고령자수':0}]
고령자3 = pd.DataFrame(고령자3)

# %%
for i in range(len(고령자)):
    if 고령자.loc[i,'자치구'] in group1:
        고령자1.loc[i,'행정동'] = 고령자.loc[i,'행정동']
        고령자1.loc[i,'고령자수'] = 고령자.loc[i,'고령자수'] #279행
고령자1.drop(0, axis=0, inplace=True)
고령자1.reset_index(drop=True,inplace=True)
고령자1
# Out:
# C:\Users\hi\AppData\Local\Temp\ipykernel_10644\3707293504.py:3: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '회기동' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   고령자1.loc[i,'행정동'] = 고령자.loc[i,'행정동']
# C:\Users\hi\AppData\Local\Temp\ipykernel_10644\3707293504.py:4: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '1552' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   고령자1.loc[i,'고령자수'] = 고령자.loc[i,'고령자수'] #279행
#         행정동  고령자수
# 0       회기동  1552
# 1      휘경1동  2164
# 2      휘경2동  4106
# 3      청량리동  5443
# 4       용신동  6103
# 5       제기동  5830
# 6      전농1동  5795
# 7      전농2동  3807
# 8     답십리2동  5774
# 9      장안1동  6780
# 10     장안2동  5419
# 11     이문1동  3218
# 12     이문2동  4110
# 13    답십리1동  4154
# 14     면목2동  4777
# 15     면목4동  3914
# ...

# %%
for i in range(len(고령자)):
    if 고령자.loc[i,'자치구'] in group2:
        고령자2.loc[i,'행정동'] = 고령자.loc[i,'행정동']
        고령자2.loc[i,'고령자수'] = 고령자.loc[i,'고령자수'] #80행
고령자2.reset_index(drop=True,inplace=True)
고령자2
# Out:
# C:\Users\hi\AppData\Local\Temp\ipykernel_10644\3875788020.py:3: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '사직동' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   고령자2.loc[i,'행정동'] = 고령자.loc[i,'행정동']
# C:\Users\hi\AppData\Local\Temp\ipykernel_10644\3875788020.py:4: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '1787' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   고령자2.loc[i,'고령자수'] = 고령자.loc[i,'고령자수'] #80행
#             행정동  고령자수
# 0           사직동  1787
# 1           삼청동   596
# 2           부암동  1808
# 3           평창동  3474
# 4           무악동  1476
# 5           교남동  1648
# 6           가회동   837
# 7   종로1.2.3.4가동  1706
# 8       종로5.6가동  1058
# 9           이화동  1352
# 10         창신1동  1176
# 11         창신2동  1809
# 12         창신3동  1250
# ...

# %%
for i in range(len(고령자)):
    if 고령자.loc[i,'자치구'] in group3:
        고령자3.loc[i,'행정동'] = 고령자.loc[i,'행정동']
        고령자3.loc[i,'고령자수'] = 고령자.loc[i,'고령자수'] #67행
고령자3.drop(0, axis=0, inplace=True)
고령자3.reset_index(drop=True,inplace=True)
고령자3
# Out:
# C:\Users\hi\AppData\Local\Temp\ipykernel_10644\839124074.py:3: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '서초1동' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   고령자3.loc[i,'행정동'] = 고령자.loc[i,'행정동']
# C:\Users\hi\AppData\Local\Temp\ipykernel_10644\839124074.py:4: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '3140' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   고령자3.loc[i,'고령자수'] = 고령자.loc[i,'고령자수'] #67행
#      행정동  고령자수
# 0   서초1동  3140
# 1   서초2동  3396
# 2   서초3동  5002
# 3   서초4동  4346
# 4    잠원동  3397
# 5   반포본동    41
# 6   반포1동  4133
# 7   반포2동  2103
# 8   반포3동  3268
# 9   반포4동  2996
# 10  방배본동  3195
# 11  방배1동  2990
# 12  방배2동  3549
# 13  방배3동  3301
# 14  방배4동  3600
# 15  양재1동  7254
# 16  양재2동  3077
# 17   내곡동  3440
# 18   신사동  3071
# ...

# %%
data1 = pd.merge(data1,고령자1, on='행정동')
data1
# Out:
#         행정동 기초생활수급자인원 노년부양비   독거노인수  고령자수
# 0       회기동       364  13.8    99.0  1552
# 1      휘경1동       386  16.6   128.0  2164
# 2      휘경2동       703  22.1   215.0  4106
# 3      청량리동      1741  43.8   915.0  5443
# 4       용신동      1680  22.3   761.0  6103
# 5       제기동      1577  30.6   772.0  5830
# 6      전농1동      1837  27.8   807.0  5795
# 7      전농2동       805  29.5   330.0  3807
# 8     답십리2동      1313  24.0   566.0  5774
# 9      장안1동      1620  23.4   481.0  6780
# 10     장안2동      1366  19.0   370.0  5419
# 11     이문1동       743  29.2   277.0  3218
# 12     이문2동      1009  20.0   401.0  4110
# 13    답십리1동       866  29.3   326.0  4154
# 14     면목2동      1715  27.1   550.0  4777
# 15     면목4동      1807  29.5   557.0  3914
# 16     면목5동       813  22.3   194.0  2375
# 17     면목7동      1137  28.5   377.0  4456
# 18     상봉1동      1714  23.2   463.0  3991
# 19     상봉2동      1103  18.7   328.0  3075
# 20     중화1동      1105  27.7   305.0  3830
# ...

# %%
data2 = pd.merge(data2,고령자2, on='행정동')
data2
# Out:
#             행정동 기초생활수급자인원  독거노인수  고령자수
# 0           사직동       125   66.0  1787
# 1           삼청동        45   23.0   596
# 2           부암동       174   74.0  1808
# 3           평창동       144   78.0  3474
# 4           무악동       206  108.0  1476
# 5           교남동       215   73.0  1648
# 6           가회동        77   27.0   837
# 7   종로1.2.3.4가동       786  423.0  1706
# 8       종로5.6가동       319  156.0  1058
# 9           이화동       288  140.0  1352
# 10         창신1동       501  216.0  1176
# 11         창신2동       491  243.0  1809
# 12         창신3동       247   84.0  1250
# 13         숭인1동       296  141.0  1206
# 14         숭인2동       475  255.0  1709
# 15        청운효자동       229   95.0  2137
# 16          혜화동       380  147.0  2675
# 17          소공동        49   17.0   258
# 18          회현동       463  221.0  1250
# 19           명동        93   32.0   733
# 20           필동       103   61.0   876
# 21          장충동       157   63.0   855
# 22          광희동       232  123.0  1090
# ...

# %%
data3 = pd.merge(data3,고령자3, on='행정동')
data3
# Out:
#      행정동 기초생활수급자인원 노년부양비   독거노인수  고령자수
# 0   서초1동       356  20.5   143.0  3140
# 1   서초2동       157  17.1    68.0  3396
# 2   서초3동       359  20.4   121.0  5002
# 3   서초4동        70  20.4    30.0  4346
# 4    잠원동       254  17.4   116.0  3397
# 5   반포본동        10  20.1     0.0    41
# 6   반포1동       458  16.6   141.0  4133
# 7   반포2동         7  20.1     5.0  2103
# 8   반포3동        41  20.3    16.0  3268
# 9   반포4동       117  21.9    37.0  2996
# 10  방배본동       361  21.5    92.0  3195
# 11  방배1동       320  24.5   137.0  2990
# 12  방배2동       493  26.8   249.0  3549
# 13  방배3동       137  27.4    53.0  3301
# 14  방배4동       335  21.1   132.0  3600
# 15  양재1동      2293  24.3   712.0  7254
# 16  양재2동       678  18.4   284.0  3077
# 17   내곡동       815  30.0   200.0  3440
# 18   신사동       246  27.4    66.0  3071
# 19  논현1동       868  16.5   157.0  2974
# 20  논현2동       489  19.8    83.0  3186
# 21  삼성1동       168  24.0    24.0  2208
# 22  삼성2동       466  16.9   109.0  3903
# ...

# %%
data3.loc[66,'기초생활수급자인원'] = 692
data3.loc[66,'노년부양비'] = 21

# %%
data3
# Out:
#      행정동 기초생활수급자인원 노년부양비   독거노인수  고령자수
# 0   서초1동       356  20.5   143.0  3140
# 1   서초2동       157  17.1    68.0  3396
# 2   서초3동       359  20.4   121.0  5002
# 3   서초4동        70  20.4    30.0  4346
# 4    잠원동       254  17.4   116.0  3397
# 5   반포본동        10  20.1     0.0    41
# 6   반포1동       458  16.6   141.0  4133
# 7   반포2동         7  20.1     5.0  2103
# 8   반포3동        41  20.3    16.0  3268
# 9   반포4동       117  21.9    37.0  2996
# 10  방배본동       361  21.5    92.0  3195
# 11  방배1동       320  24.5   137.0  2990
# 12  방배2동       493  26.8   249.0  3549
# 13  방배3동       137  27.4    53.0  3301
# 14  방배4동       335  21.1   132.0  3600
# 15  양재1동      2293  24.3   712.0  7254
# 16  양재2동       678  18.4   284.0  3077
# 17   내곡동       815  30.0   200.0  3440
# 18   신사동       246  27.4    66.0  3071
# 19  논현1동       868  16.5   157.0  2974
# 20  논현2동       489  19.8    83.0  3186
# 21  삼성1동       168    24    24.0  2208
# 22  삼성2동       466  16.9   109.0  3903
# ...

# %%
data1.to_csv('group1_data.csv')
data2.to_csv('group2_data.csv')
data3.to_csv('group3_data.csv')
