# %%
from google.colab import drive
import pandas as pd

# %%
income = pd.read_csv('/content/데이터_서울시 행정동 소득.csv')

# %%
income.head()
# Out:
#          adstrd_nm   adstrd_cd legaldong_nm  legaldong_cd  tot_popltn_co  \
# 0  서울특별시 종로구 청운효자동  1111051500          세종로    1111011900          12842
# 1  서울특별시 종로구 청운효자동  1111051500          옥인동    1111011100          12842
# 2  서울특별시 종로구 청운효자동  1111051500          누하동    1111011000          12842
# 3  서울특별시 종로구 청운효자동  1111051500          누상동    1111010900          12842
# 4  서울특별시 종로구 청운효자동  1111051500          통인동    1111010800          12842
#
#    tot_hshld_co  hshld_pprty_popltn_co  avrg_income_am
# 0          5364                   2.39         7271.00
# 1          5364                   2.39         4639.23
# 2          5364                   2.39         4162.85
# 3          5364                   2.39         3634.44
# 4          5364                   2.39         4515.56

# %%
income['address'] = income['adstrd_nm'] + " " + income['legaldong_nm']

# %%
income = income.drop(['adstrd_nm','tot_hshld_co','legaldong_nm'],axis=1)
income.head()
# Out:
#     adstrd_cd  legaldong_cd  tot_popltn_co  hshld_pprty_popltn_co  \
# 0  1111051500    1111011900          12842                   2.39
# 1  1111051500    1111011100          12842                   2.39
# 2  1111051500    1111011000          12842                   2.39
# 3  1111051500    1111010900          12842                   2.39
# 4  1111051500    1111010800          12842                   2.39
#
#    avrg_income_am              address
# 0         7271.00  서울특별시 종로구 청운효자동 세종로
# 1         4639.23  서울특별시 종로구 청운효자동 옥인동
# 2         4162.85  서울특별시 종로구 청운효자동 누하동
# 3         3634.44  서울특별시 종로구 청운효자동 누상동
# 4         4515.56  서울특별시 종로구 청운효자동 통인동

# %%
income = income.sort_values('avrg_income_am',ascending=False)
income
# Out:
#       adstrd_cd  legaldong_cd  tot_popltn_co  hshld_pprty_popltn_co  \
# 107  1114055000    1114012700           2835                   1.97
# 66   1111061500    1111012500           7331                   1.39
# 638  1168054500    1168011000          27607                   2.58
# 634  1168051000    1168011000          17348                   2.32
# 108  1114055000    1114012600           2835                   1.97
# ..          ...           ...            ...                    ...
# 135  1114059000    1114014900           4931                   1.68
# 129  1114057000    1114013300           4021                   1.75
# 142  1114059000    1114013300           4931                   1.68
# 491  1150062000    1150011300          27419                   2.15
# 134  1114059000    1114015400           4931                   1.68
#
#      avrg_income_am                    address
# 107        16112.00           서울특별시 중구 명동 명동2가
# 66         14089.50  서울특별시 종로구 종로1.2.3.4가동 중학동
# ...

# %%
income = income.drop(columns = 'address')
income
# Out:
#       adstrd_cd  legaldong_cd  tot_popltn_co  hshld_pprty_popltn_co  \
# 107  1114055000    1114012700           2835                   1.97
# 66   1111061500    1111012500           7331                   1.39
# 638  1168054500    1168011000          27607                   2.58
# 634  1168051000    1168011000          17348                   2.32
# 108  1114055000    1114012600           2835                   1.97
# ..          ...           ...            ...                    ...
# 135  1114059000    1114014900           4931                   1.68
# 129  1114057000    1114013300           4021                   1.75
# 142  1114059000    1114013300           4931                   1.68
# 491  1150062000    1150011300          27419                   2.15
# 134  1114059000    1114015400           4931                   1.68
#
#      avrg_income_am
# 107        16112.00
# 66         14089.50
# 638        13470.70
# 634        13470.70
# 108        13040.33
# ..              ...
# ...

# %%
import numpy as np

# %%
from scipy.stats import normaltest
import numpy as np

# %%
jal = income[0:237]

# %%
jal.describe()
# Out:
#           adstrd_cd  legaldong_cd  tot_popltn_co  hshld_pprty_popltn_co  \
# count  2.370000e+02  2.370000e+02     237.000000             237.000000
# mean   1.141864e+09  1.141815e+09   19395.843882               2.275063
# std    2.451235e+07  2.451008e+07   11133.519729               0.419164
# min    1.111052e+09  1.111010e+09     272.000000               1.390000
# 25%    1.114058e+09  1.114017e+09   10624.000000               1.980000
# 50%    1.144066e+09  1.144012e+09   18677.000000               2.300000
# 75%    1.168054e+09  1.168010e+09   26981.000000               2.530000
# max    1.174070e+09  1.174011e+09   48039.000000               3.410000
#
#        avrg_income_am
# count      237.000000
# mean      6991.998903
# std       1832.234843
# min       5283.920000
# 25%       5684.270000
# 50%       6458.050000
# 75%       7385.290000
# max      16112.000000

# %%
mid = income[238:475]
mid
# Out:
#       adstrd_cd  legaldong_cd  tot_popltn_co  hshld_pprty_popltn_co  \
# 582  1159063000    1159010700          27975                   2.34
# 584  1159064000    1159010700          25973                   2.44
# 581  1159062000    1159010700          23463                   1.80
# 585  1159065000    1159010700          14698                   2.11
# 111  1114055000    1114012300           2835                   1.97
# ..          ...           ...            ...                    ...
# 525  1154568000    1154510300          22620                   2.69
# 528  1154571000    1154510300          20291                   2.18
# 148  1114060500    1114015600           1806                   1.34
# 470  1150051000    1150010400          42352                   2.72
# 485  1150060500    1150010400          16166                   2.04
#
#      avrg_income_am
# 582         5279.06
# 584         5279.06
# 581         5279.06
# 585         5279.06
# 111         5270.82
# ..              ...
# ...

# %%
jal.groupby('tot_popltn_co')

# %%
jal.describe()
# Out:
#           adstrd_cd  legaldong_cd  tot_popltn_co  hshld_pprty_popltn_co  \
# count  2.370000e+02  2.370000e+02     237.000000             237.000000
# mean   1.141864e+09  1.141815e+09   19395.843882               2.275063
# std    2.451235e+07  2.451008e+07   11133.519729               0.419164
# min    1.111052e+09  1.111010e+09     272.000000               1.390000
# 25%    1.114058e+09  1.114017e+09   10624.000000               1.980000
# 50%    1.144066e+09  1.144012e+09   18677.000000               2.300000
# 75%    1.168054e+09  1.168010e+09   26981.000000               2.530000
# max    1.174070e+09  1.174011e+09   48039.000000               3.410000
#
#        avrg_income_am
# count      237.000000
# mean      6991.998903
# std       1832.234843
# min       5283.920000
# 25%       5684.270000
# 50%       6458.050000
# 75%       7385.290000
# max      16112.000000

# %%
mot = income[476:713]
mot
# Out:
#       adstrd_cd  legaldong_cd  tot_popltn_co  hshld_pprty_popltn_co  \
# 483  1150060300    1150010400          33838                   1.78
# 560  1156062000    1156012800          22628                   2.24
# 166  1114068000    1114017100          12682                   2.17
# 272  1129052500    1129010700          17111                   2.13
# 370  1138052000    1138010300          40730                   2.28
# ..          ...           ...            ...                    ...
# 537  1156053500    1156010300          26428                   1.54
# 135  1114059000    1114014900           4931                   1.68
# 129  1114057000    1114013300           4021                   1.75
# 142  1114059000    1114013300           4931                   1.68
# 491  1150062000    1150011300          27419                   2.15
#
#      avrg_income_am
# 483         4226.67
# 560         4220.78
# 166         4212.42
# 272         4203.45
# 370         4199.49
# ..              ...
# ...

# %%
mot.describe()
# Out:
#           adstrd_cd  legaldong_cd  tot_popltn_co  hshld_pprty_popltn_co  \
# count  2.370000e+02  2.370000e+02     237.000000             237.000000
# mean   1.131858e+09  1.131809e+09   19078.489451               2.001772
# std    1.634721e+07  1.634530e+07   10070.784543               0.349131
# min    1.111052e+09  1.111010e+09    1806.000000               1.300000
# 25%    1.114068e+09  1.114017e+09   11588.000000               1.710000
# 50%    1.129062e+09  1.129013e+09   19082.000000               2.050000
# 75%    1.147058e+09  1.147010e+09   25472.000000               2.240000
# max    1.171061e+09  1.171011e+09   53531.000000               2.840000
#
#        avrg_income_am
# count      237.000000
# mean      3688.220928
# std        438.081820
# min       2241.000000
# 25%       3443.010000
# 50%       3796.310000
# 75%       3999.830000
# max       4226.670000

# %%
from scipy import stats
stats.ttest_ind(jal, mid)
# Out:
# TtestResult(statistic=array([ 2.06764206,  2.06880198, -2.17002366,  2.72652834, 19.02691833]), pvalue=array([3.92180762e-02, 3.91085537e-02, 3.05031264e-02, 6.63865058e-03,
#        2.49456097e-60]), df=array([472., 472., 472., 472., 472.]))

# %%
stats.ttest_ind(jal,mot)
# Out:
# TtestResult(statistic=array([ 5.22809305,  5.22876507,  0.32543551,  7.71239931, 26.99802621]), pvalue=array([2.57759315e-07, 2.56875493e-07, 7.44995694e-01, 7.38733413e-14,
#        9.11645271e-98]), df=array([472., 472., 472., 472., 472.]))

# %%
stats.ttest_ind(mot, mid)
# Out:
# TtestResult(statistic=array([ -3.68019613,  -3.67945123,  -2.61365397,  -5.482338  ,
#        -29.04437977]), pvalue=array([2.59934526e-004, 2.60673515e-004, 9.24407259e-003, 6.84833247e-008,
#        3.97807888e-107]), df=array([472., 472., 472., 472., 472.]))

# %%
# sort by value in descending order per group, and select top 3 values per group
income = income.groupby("tot_popltn_co")
income

# %%
from pandas import Series, DataFrame

import matplotlib.pyplot as plt
