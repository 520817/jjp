# %%
# !pip install geopy

# %%
import pandas as pd
import numpy as np

# %%
add = pd.read_csv('/content/Group 1.csv')
address = add[['도로명주소']]
address
# Out:
#                     도로명주소
# 0        서울 강서구 양천로57길 37
# 1          서울 노원구 노원로 333
# 2    서울 강북구 한천로109길 57-12
# 3     서울 도봉구 도봉로173길 40-5
# 4   서울 관악구 대학12길 16 1층~2층
# ..                    ...
# 63    서울 성북구 보국문로17길 18-6
# 64    서울 동작구 노량진로6길 50-14
# 65         서울 강북구 인수봉로 42
# 66       서울 강북구 솔샘로 277-1
# 67       도봉구 도담로 2길 12-13
#
# [68 rows x 1 columns]

# %%
add2.head(3)
# Out:
#    자치구   행정동          시설명                        상세주소
# 0  광진구  중곡4동        대원경로당  서울 광진구 긴고랑로36길 57-27 대원경로당
# 1   중구   약수동  구립약수노인종합복지관     서울 중구 다산로6길 11 약수동 복지회관
# 2   중구  을지로동        을지경로당       서울 중구 을지로28길 16 을지경로당

# %%
add2 = pd.read_csv('/content/Group2_최종위치.csv')
address2 = add2[['상세주소']]
address2
# Out:
#                           상세주소
# 0   서울 광진구 긴고랑로36길 57-27 대원경로당
# 1      서울 중구 다산로6길 11 약수동 복지회관
# 2        서울 중구 을지로28길 16 을지경로당
# 3            서울 종로구 종로54길 9-23
# 4              서울 광진구 동일로2길 17
# 5              서울 중구 퇴계로12길 89
# 6                서울 종로구 창신길 98
# 7              서울 용산구 장문로19길 1
# 8               서울 중구 청구로3길 69
# 9             서울 광진구 동일로80길 20
# 10    서울 용산구 청파로83길 26 청파노인복지관
# 11          서울 광진구 자양로38길 17-5
# 12           서울 광진구 아차산로40길 46
# 13           서울 성동구 천호대로78길 42
# 14             서울 중구 동호로12길 97

# %%
import pandas as pd
# csv파일 불러오기
csv = pd.read_csv('/content/3그룹행정통일후에.csv')
print(csv.head())
# Out:
#               센터명   행정동                   도로명주소                   일반주소
# 0       강남노인종합복지관  삼성1동       서울특별시 강남구 삼성로 628       서울특별시 강남구 삼성동 66
# 1        강남시니어플라자  역삼1동      서울특별시 강남구 봉은사로 332    서울특별시 강남구 역삼동 682-8
# 2       논현노인종합복지관  논현1동   서울특별시 강남구 강남대로128길 59   서울특별시 강남구 논현동 125-13
# 3      서초노인주간보건센터  양재1동  서울특별시 서초구 강남대로30길 73-7     서울특별시 서초구 양재동 7-44
# 4  서초구립 중앙노인종합복지관  서초1동    서울특별시 서초구 서초대로54길 45  서울특별시 서초구 서초동 1666-17

# %%
import pandas as pd
# csv파일 불러오기
csv = pd.read_csv('/content/Group 1.csv')
print(csv.head())
# Out:
#    자치구     행정동         센터명                  도로명주소 Unnamed: 4
# 0  강서구    가양2동  가양4종합사회복지관       서울 강서구 양천로57길 37        NaN
# 1  노원구  중계2,3동   평화종합사회복지관         서울 노원구 노원로 333        NaN
# 2  강북구     번3동       골말경로당   서울 강북구 한천로109길 57-12        NaN
# 3  도봉구    도봉1동       무수경로당    서울 도봉구 도봉로173길 40-5        NaN
# 4  관악구     삼성동       대학경로당  서울 관악구 대학12길 16 1층~2층        NaN

# %%
address.astype('str')
# Out:
#                     도로명주소
# 0        서울 강서구 양천로57길 37
# 1          서울 노원구 노원로 333
# 2    서울 강북구 한천로109길 57-12
# 3     서울 도봉구 도봉로173길 40-5
# 4   서울 관악구 대학12길 16 1층~2층
# ..                    ...
# 63    서울 성북구 보국문로17길 18-6
# 64    서울 동작구 노량진로6길 50-14
# 65         서울 강북구 인수봉로 42
# 66       서울 강북구 솔샘로 277-1
# 67       도봉구 도담로 2길 12-13
#
# [68 rows x 1 columns]

# %%
address2.astype('str')
# Out:
#                           상세주소
# 0   서울 광진구 긴고랑로36길 57-27 대원경로당
# 1      서울 중구 다산로6길 11 약수동 복지회관
# 2        서울 중구 을지로28길 16 을지경로당
# 3            서울 종로구 종로54길 9-23
# 4              서울 광진구 동일로2길 17
# 5              서울 중구 퇴계로12길 89
# 6                서울 종로구 창신길 98
# 7              서울 용산구 장문로19길 1
# 8               서울 중구 청구로3길 69
# 9             서울 광진구 동일로80길 20
# 10    서울 용산구 청파로83길 26 청파노인복지관
# 11          서울 광진구 자양로38길 17-5
# 12           서울 광진구 아차산로40길 46
# 13           서울 성동구 천호대로78길 42
# 14             서울 중구 동호로12길 97

# %%
addr = pd.read_csv('/content/Group2_최종위치.csv')
addr
# Out:
#     자치구   행정동          시설명                        상세주소
# 0   광진구  중곡4동        대원경로당  서울 광진구 긴고랑로36길 57-27 대원경로당
# 1    중구   약수동  구립약수노인종합복지관     서울 중구 다산로6길 11 약수동 복지회관
# 2    중구  을지로동        을지경로당       서울 중구 을지로28길 16 을지경로당
# 3   종로구  창신1동        창일노인정           서울 종로구 종로54길 9-23
# 4   광진구  자양4동    자양4동제2경로당             서울 광진구 동일로2길 17
# 5    중구   회현동      구립회현경로당             서울 중구 퇴계로12길 89
# 6   종로구  창신2동      창신2동경로당               서울 종로구 창신길 98
# 7   용산구   보광동       보광동노인회             서울 용산구 장문로19길 1
# 8    중구   청구동        청구경로당              서울 중구 청구로3길 69
# 9   광진구  중곡3동      중곡3동경로당            서울 광진구 동일로80길 20
# 10  용산구   청파동      청파노인복지관    서울 용산구 청파로83길 26 청파노인복지관
# 11  광진구  구의2동      구의2동경로당          서울 광진구 자양로38길 17-5
# 12  광진구  자양1동      자양1동경로당           서울 광진구 아차산로40길 46
# 13  성동구   용답동     용답동노인복지관           서울 성동구 천호대로78길 42
# 14   중구   다산동       다산동경로당             서울 중구 동호로12길 97

# %%
# 데이터프레임 주소값 추출
address2= address2['상세주소']
print(address2.head())
# Out:
# 0    서울 광진구 긴고랑로36길 57-27 대원경로당
# 1       서울 중구 다산로6길 11 약수동 복지회관
# 2         서울 중구 을지로28길 16 을지경로당
# 3             서울 종로구 종로54길 9-23
# 4               서울 광진구 동일로2길 17
# Name: 상세주소, dtype: object

# %%
# 주소 데이터 깔끔하게 다듬기
for i in range(len(address2)):
    a = address2[i].split(' ')
    address2[i] = " ".join(a[0:4])
print(address2)
# Out:
# 0     서울 광진구 긴고랑로36길 57-27
# 1           서울 중구 다산로6길 11
# 2          서울 중구 을지로28길 16
# 3        서울 종로구 종로54길 9-23
# 4          서울 광진구 동일로2길 17
# 5          서울 중구 퇴계로12길 89
# 6            서울 종로구 창신길 98
# 7          서울 용산구 장문로19길 1
# 8           서울 중구 청구로3길 69
# 9         서울 광진구 동일로80길 20
# 10        서울 용산구 청파로83길 26
# 11      서울 광진구 자양로38길 17-5
# 12       서울 광진구 아차산로40길 46
# 13       서울 성동구 천호대로78길 42
# 14         서울 중구 동호로12길 97
# Name: 상세주소, dtype: object
# <ipython-input-29-d691e1daa2f6>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   address2[i] = " ".join(a[0:4])

# %%
address2.head(3)
# Out:
# 0    서울 광진구 긴고랑로36길 57-27
# 1          서울 중구 다산로6길 11
# 2         서울 중구 을지로28길 16
# Name: 상세주소, dtype: object

# %%
####### 도로명주소 위도 경도 값으로 바꿔주기 ########
from geopy.geocoders import Nominatim
geo_local = Nominatim(user_agent='South Korea')

# 위도, 경도 반환하는 함수
def geocoding(address2):
    try:
        geo = geo_local.geocode(address2)
        x_y = [geo.latitude, geo.longitude]
        return x_y

    except:
        return [0,0]

# %%
addr.columns
# Out:
# Index(['자치구', '행정동', '시설명', '상세주소'], dtype='object')

# %%
#####주소를 위,경도 값으로 변환하기 #####
latitude = []
longitude =[]

for i in address2:
    latitude.append(geocoding(i)[0])
    longitude.append(geocoding(i)[1])

#####Dataframe만들기######
address_df2 = pd.DataFrame({'시설명': addr['시설명'],'도로명주소':addr['상세주소'],'위도':latitude,'경도':longitude})

#df저장
address_df2.to_csv('gr2.csv')

# %%
# 데이터프레임 주소값 추출
address= csv['도로명주소']
print(address.head())
# Out:
# 0         서울 강서구 양천로57길 37
# 1           서울 노원구 노원로 333
# 2     서울 강북구 한천로109길 57-12
# 3      서울 도봉구 도봉로173길 40-5
# 4    서울 관악구 대학12길 16 1층~2층
# Name: 도로명주소, dtype: object

# %%
address = address.astype('str')

# %%
# 주소 데이터 깔끔하게 다듬기
for i in range(len(address)):
    a = address[i].split(' ')
    address[i] = " ".join(a[0:4])
print(address)
# Out:
# 0          서울 강서구 양천로57길 37
# 1            서울 노원구 노원로 333
# 2      서울 강북구 한천로109길 57-12
# 3       서울 도봉구 도봉로173길 40-5
# 4     서울 관악구 대학12길 16 1층~2층
#               ...
# 63      서울 성북구 보국문로17길 18-6
# 64      서울 동작구 노량진로6길 50-14
# 65           서울 강북구 인수봉로 42
# 66         서울 강북구 솔샘로 277-1
# 67         도봉구 도담로 2길 12-13
# Name: 도로명주소, Length: 68, dtype: object

# %%
####### 도로명주소 위도 경도 값으로 바꿔주기 ########
from geopy.geocoders import Nominatim
geo_local = Nominatim(user_agent='South Korea')

# 위도, 경도 반환하는 함수
def geocoding(address):
    try:
        geo = geo_local.geocode(address)
        x_y = [geo.latitude, geo.longitude]
        return x_y

    except:
        return [0,0]

# %%
#####주소를 위,경도 값으로 변환하기 #####
latitude = []
longitude =[]

for i in address:
    latitude.append(geocoding(i)[0])
    longitude.append(geocoding(i)[1])

#####Dataframe만들기######
address_df = pd.DataFrame({'시설명': csv['센터명'],'도로명주소':csv['도로명주소'],'주소':address,'위도':latitude,'경도':longitude})

#df저장
address_df.to_csv('으악2.csv')

# %%
csv.columns
# Out:
# Index(['센터명', '행정동', '도로명주소', '일반주소'], dtype='object')

# %%
####### 도로명주소 위도 경도 값으로 바꿔주기 ########
from geopy.geocoders import Nominatim
geo_local = Nominatim(user_agent='South Korea')

# 위도, 경도 반환하는 함수
def geocoding(address):
    try:
        geo = geo_local.geocode(address)
        x_y = [geo.latitude, geo.longitude]
        return x_y

    except:
        return [0,0]

# %%
latitude = []
longitude =[]

for i in address:
    latitude.append(geocoding(i)[0])
    longitude.append(geocoding(i)[1])
# Out:
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)")': /search?q=%EC%84%9C%EC%9A%B8%C2%A0%EC%9D%80%ED%8F%89%EA%B5%AC%C2%A0%EC%97%B0%EC%84%9C%EB%A1%9C33%EA%B8%B8%C2%A014-19&format=json&limit=1
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)")': /search?q=%EC%84%9C%EC%9A%B8+%EA%B0%95%EB%B6%81%EA%B5%AC+%EB%8D%95%EB%A6%89%EB%A1%9C41%EA%B8%B8+92&format=json&limit=1

# %%
latitude
# Out:
# [37.5659531,
#  37.6215438,
#  37.6278414,
#  37.6789188,
#  0,
#  37.5883765,
#  37.6214025,
#  37.6339727,
#  37.6450978,
#  37.6222126,
#  0,
#  0,
#  37.5848978,
#  37.6704811,
#  37.595017,
#  37.6387469,
#  37.6454832,
#  37.6681251,
#  37.5861918,
#  37.6610137,
#  37.6574095,
#  37.4694679,
#  37.6681251,
#  37.6693699,
#  37.5664168,
#  37.5312794,
#  37.5364933,
#  46.3144754,
#  37.6046428,
#  37.59575245,
#  37.6772303,
#  37.6327289,
#  37.624011,
#  37.5289172,
#  37.6280605,
#  0,
#  37.6104377,
#  37.6143549,
#  37.5098187,
#  37.6239254,
#  37.6364286,
#  37.578912,
#  37.4496111,
#  37.5899297,
#  37.4891959,
#  37.637012,
#  37.6098029,
#  37.5830882,
#  0,
#  37.5470468,
#  37.4829694,
#  37.5392477,
#  37.6247424,
#  37.6250258,
#  37.6673213,
#  0,
#  0,
#  37.6225567,
#  37.5289172,
#  37.6364286,
#  37.4978486,
#  37.4914021,
#  37.5790001,
#  37.6112022,
#  37.5098187,
#  37.6335413,
#  37.6214025,
#  0]

# %%
#####Dataframe만들기######
address_df = pd.DataFrame({'주소':address,'위도':latitude,'경도':longitude})

# %%
address_df.to_csv('그룹1.csv')

# %%
add.columns
# Out:
# Index(['센터명', '행정동', '도로명주소', '일반주소'], dtype='object')
