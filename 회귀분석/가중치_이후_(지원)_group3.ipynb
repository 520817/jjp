# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import folium
import json
import numpy as np
import statsmodels.api as sm

# %%
group3 = pd.read_csv('/content/group3.csv',encoding='cp949')

# %%
group3.head(5)
# Out:
#    Unnamed: 0  자치구   행정동  기초생활수급자인원  노년부양비  독거노인수  고령내국인전체  노령화지수  무료급식소개수
# 0           0  서초구  서초1동        356   20.5    143     3140  144.9        1
# 1           1  서초구  서초2동        157   17.1     68     3396   94.6        0
# 2           2  서초구  서초3동        359   20.4    121     5002  177.9        0
# 3           3  서초구  서초4동         70   20.4     30     4346   90.0        0
# 4           4  서초구   잠원동        254   17.4    116     3397   98.0        0

# %%
group3 = group3.drop(['Unnamed: 0'],axis=1)
group3.head(5)
# Out:
#    자치구   행정동  기초생활수급자인원  노년부양비  독거노인수  고령내국인전체  노령화지수  무료급식소개수
# 0  서초구  서초1동        356   20.5    143     3140  144.9        1
# 1  서초구  서초2동        157   17.1     68     3396   94.6        0
# 2  서초구  서초3동        359   20.4    121     5002  177.9        0
# 3  서초구  서초4동         70   20.4     30     4346   90.0        0
# 4  서초구   잠원동        254   17.4    116     3397   98.0        0

# %%
data.head(1)
# Out:
#    자치구   행정동  기초생활수급자인원  노년부양비  독거노인수  고령내국인전체  노령화지수  무료급식소개수  저체중률
# 0  서초구  서초1동        356   20.5    143     3140  144.9        1   8.3

# %%
data = pd.merge(group3,weight, on='자치구')

# %%
from sklearn.preprocessing import StandardScaler
ss = StandardScaler()
data2 = pd.DataFrame(ss.fit_transform(data.iloc[:,[2,3,5,6,7,8]]))
data2.rename(columns={0:'기초생활수급자인원',1:'노년부양비',2:'고령내국인전체',3:'노령화지수',4:'무료급식소개수'},inplace=True)
data2=pd.concat([data2,data.loc[:,'저체중률']],axis=1)

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
vif = pd.DataFrame()
group3_ss=data2.drop('저체중률',axis=1)
# Out:
#     기초생활수급자인원     노년부양비   고령내국인전체     노령화지수   무료급식소개수         5
# 0   -0.358217 -0.293011 -0.468145 -0.203908  1.243799  1.416472
# 1   -0.668193 -0.790386 -0.249788 -0.770945 -0.456906  1.416472
# 2   -0.353544 -0.307639  1.120057  0.168104 -0.456906  1.416472
# 3   -0.803710 -0.307639  0.560519 -0.822802 -0.456906  1.416472
# 4   -0.517099 -0.746500 -0.248936 -0.732617 -0.456906  1.416472
# ..        ...       ...       ...       ...       ...       ...
# 62  -0.895612  0.540825  2.031013 -0.423734 -0.456906 -1.061604
# 63  -0.861343 -0.117466  0.790816 -0.211800 -0.456906 -1.061604
# 64  -0.828632 -1.580336 -0.090286 -1.443949 -0.456906 -1.061604
# 65   1.704134 -0.761129  0.176689  0.598736 -0.456906 -1.061604
# 66   0.785111 -0.249125 -0.609735 -0.990771 -0.456906 -1.061604
#
# [67 rows x 6 columns]

# %%
from statsmodels.formula.api import ols

ols('저체중률 ~ 기초생활수급자인원+노년부양비+고령내국인전체+노령화지수+무료급식소개수', data=data2).fit().summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                   저체중률   R-squared:                       0.171
# Model:                            OLS   Adj. R-squared:                  0.103
# Method:                 Least Squares   F-statistic:                     2.511
# Date:                Sun, 05 Nov 2023   Prob (F-statistic):             0.0393
# Time:                        12:16:41   Log-Likelihood:                -115.66
# No. Observations:                  67   AIC:                             243.3
# Df Residuals:                      61   BIC:                             256.5
# Df Model:                           5
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      6.1851      0.174     35.528      0.000       5.837       6.533
# 기초생활수급자인원     -0.1528      0.293     -0.521      0.604      -0.739       0.434
# 노년부양비          0.2720      0.243      1.118      0.268      -0.214       0.758
# 고령내국인전체       -0.2707      0.208     -1.303      0.198      -0.686       0.145
# 노령화지수         -0.5809      0.296     -1.964      0.054      -1.172       0.011
# 무료급식소개수        0.5425      0.213      2.545      0.013       0.116       0.969
# ==============================================================================
# Omnibus:                        8.232   Durbin-Watson:                   0.440
# Prob(Omnibus):                  0.016   Jarque-Bera (JB):                3.259
# Skew:                           0.221   Prob(JB):                        0.196
# Kurtosis:                       2.014   Cond. No.                         3.67
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
weight = pd.read_csv('/content/저체중률.csv',encoding='cp949')
weight = weight.drop(['Unnamed: 0'],axis=1)
weight.head(3)
# Out:
#    자치구  저체중률
# 0  종로구   5.3
# 1   중구   5.3
# 2  용산구   3.8

# %%
group3_score = group3.copy()
group3_score= group3_score[['자치구','행정동']]
group3_score['점수'] = 0
group3_score['순위'] = 0
group3_score['점수'] = group3_score['점수'].astype('float')
group3_score['순위'] = group3_score['순위'].astype('int')
group3_score.head()
# Out:
#    자치구   행정동   점수  순위
# 0  서초구  서초1동  0.0   0
# 1  서초구  서초2동  0.0   0
# 2  서초구  서초3동  0.0   0
# 3  서초구  서초4동  0.0   0
# 4  서초구   잠원동  0.0   0

# %%
def score(dataframe1, dataframe2):
    for i in range(len(dataframe1)):
        dataframe1.loc[i,'점수'] = 0.167 * dataframe2.loc[i,'기초생활수급자인원'] + 0.185 * dataframe2.loc[i,'고령내국인전체'] + 0.216 * dataframe2.loc[i,'노년부양비'] + 0.265 * dataframe2.loc[i,'노령화지수'] + 0.167 * dataframe2.loc[i,'무료급식소개수']
    dataframe1 = dataframe1.sort_values('점수', ascending=False)
    dataframe1 = dataframe1.reset_index(drop=True)
def rank(dataframe):
    for j in range(len(dataframe)):
        dataframe.loc[j,'순위'] = j+1

# %%
pd.set_option('display.max_rows', None)
score(group3_score,data2)

# %%
group3_score = group3_score.sort_values('점수', ascending=False)
group3_score.reset_index(drop=True,inplace=True)

rank(group3_score)
group3_score
# Out:
#     자치구   행정동        점수  순위
# 0   강남구   수서동  3.877404   1
# 1   서초구  양재1동  1.742694   2
# 2   강남구  일원1동  1.464329   3
# 3   송파구  방이1동  1.154706   4
# 4   송파구  마천2동  1.036250   5
# 5   강남구   세곡동  1.026036   6
# 6   송파구  송파1동  0.803489   7
# 7   송파구  풍납2동  0.449515   8
# 8   서초구  방배2동  0.415575   9
# 9   강남구  논현1동  0.402241  10
# 10  송파구  가락본동  0.375272  11
# 11  강남구  압구정동  0.311624  12
# 12  강남구  역삼1동  0.270393  13
# 13  송파구  거여2동  0.263821  14
# 14  송파구   삼전동  0.235803  15
# 15  송파구   위례동  0.235236  16
# 16  송파구  풍납1동  0.217239  17
# 17  송파구  잠실6동  0.197878  18
# 18  송파구  잠실2동  0.154396  19
# 19  송파구  마천1동  0.149378  20
# 20  강남구  개포1동  0.128202  21
# 21  서초구   내곡동  0.099676  22
# 22  송파구   오륜동  0.069551  23
# 23  서초구  서초3동  0.049963  24
# 24  송파구  송파2동  0.007201  25
# 25  송파구  가락1동 -0.005940  26
# 26  강남구   신사동 -0.013958  27
# 27  송파구  잠실4동 -0.052385  28
# 28  서초구  서초1동 -0.056041  29
# 29  송파구  거여1동 -0.058566  30
# 30  강남구  삼성1동 -0.061656  31
# 31  서초구  방배3동 -0.086380  32
# 32  강남구  논현2동 -0.128233  33
# 33  서초구  방배1동 -0.134973  34
# 34  송파구  잠실3동 -0.155346  35
# 35  강남구  도곡2동 -0.160432  36
# 36  송파구  잠실본동 -0.176741  37
# 37  강남구  대치2동 -0.180593  38
# 38  송파구  문정1동 -0.183294  39
# 39  강남구  개포2동 -0.189994  40
# 40  송파구  문정2동 -0.197549  41
# 41  송파구  가락2동 -0.212427  42
# 42  강남구  개포4동 -0.251445  43
# 43  서초구  양재2동 -0.277327  44
# 44  서초구  방배4동 -0.298786  45
# 45  강남구  역삼2동 -0.305862  46
# 46  강남구   청담동 -0.314653  47
# 47  송파구   석촌동 -0.337674  48
# 48  송파구   오금동 -0.354510  49
# 49  서초구  방배본동 -0.374061  50
# 50  강남구  개포3동 -0.374356  51
# 51  서초구  서초4동 -0.391319  52
# 52  강남구  삼성2동 -0.442516  53
# 53  서초구  반포1동 -0.480518  54
# 54  서초구  반포4동 -0.488858  55
# 55  강남구  일원본동 -0.497450  56
# 56  송파구  방이2동 -0.502864  57
# 57  강남구  도곡1동 -0.506756  58
# 58  서초구  반포3동 -0.552710  59
# 59  서초구   잠원동 -0.564099  60
# 60  서초구  서초2동 -0.609126  61
# 61  강남구  대치4동 -0.675379  62
# 62  송파구  잠실7동 -0.695664  63
# 63  서초구  반포2동 -0.840432  64
# 64  강남구  대치1동 -0.887526  65
# 65  송파구   장지동 -0.955387  66
# 66  서초구  반포본동 -1.104086  67
