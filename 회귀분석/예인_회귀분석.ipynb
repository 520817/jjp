# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
import seaborn as sns
import statsmodels.api as sm

# %%
group2 = pd.read_csv('./data/group2.csv', index_col=0)
group2
# Out:
#     자치구          행정동  기초생활수급자인원  노년부양비  독거노인수  고령내국인전체  노령화지수  무료급식소개수  저체중률
# 0   종로구          사직동      125.0   27.1   66.0   1787.0  208.3      0.0   5.3
# 1   종로구          삼청동       45.0   35.1   23.0    596.0  266.4      0.0   5.3
# 2   종로구          부암동      174.0   26.2   74.0   1808.0  225.6      0.0   5.3
# 3   종로구          평창동      144.0   27.8   78.0   3474.0  192.8      0.0   5.3
# 4   종로구          무악동      206.0   26.7  108.0   1476.0  141.0      0.0   5.3
# 5   종로구          교남동      215.0   23.1   73.0   1648.0  140.2      0.0   5.3
# 6   종로구          가회동       77.0   29.2   27.0    837.0  244.2      0.0   5.3
# 7   종로구  종로1.2.3.4가동      786.0   27.7  423.0   1706.0  297.8      0.0   5.3
# 8   종로구      종로5.6가동      319.0   23.7  156.0   1058.0  435.9      0.0   5.3
# 9   종로구          이화동      288.0   23.0  140.0   1352.0  381.5      0.0   5.3
# 10  종로구         창신1동      501.0   29.8  216.0   1176.0  555.1      0.0   5.3
# 11  종로구         창신2동      491.0   28.1  243.0   1809.0  487.6      0.0   5.3
# 12  종로구         창신3동      247.0   26.0   84.0   1250.0  230.8      0.0   5.3
# 13  종로구         숭인1동      296.0   27.2  141.0   1206.0  316.4      0.0   5.3
# 14  종로구         숭인2동      475.0   20.5  255.0   1709.0  455.8      0.0   5.3
# 15  종로구        청운효자동      229.0   25.6   95.0   2137.0  173.7      0.0   5.3
# 16  종로구          혜화동      380.0   17.2  147.0   2675.0  242.9      0.0   5.3
# 17   중구          소공동       49.0   11.3   17.0    258.0   73.1      0.0   5.3
# 18   중구          회현동      463.0   37.4  221.0   1250.0  367.5      0.0   5.3
# 19   중구           명동       93.0   29.2   32.0    733.0  389.0      0.0   5.3
# 20   중구           필동      103.0   24.1   61.0    876.0  349.8      0.0   5.3
# 21   중구          장충동      157.0   20.7   63.0    855.0  304.9      0.0   5.3
# 22   중구          광희동      232.0   21.2  123.0   1090.0  447.8      0.0   5.3
# 23   중구         을지로동      148.0   34.1   98.0    454.0  659.2      0.0   5.3
# 24   중구         신당5동      511.0   23.8  232.0   1860.0  248.7      0.0   5.3
# 25   중구          황학동      536.0   20.0  234.0   2035.0  212.8      0.0   5.3
# 26   중구          중림동      622.0   25.1  254.0   2187.0  162.1      2.0   5.3
# 27   중구          신당동      440.0   21.2  215.0   1486.0  370.9      0.0   5.3
# 28   중구          다산동      507.0   27.4  233.0   2807.0  335.2      0.0   5.3
# 29   중구          약수동      944.0   35.7  528.0   3980.0  284.4      0.0   5.3
# 30   중구          청구동      769.0   29.7  365.0   2840.0  275.0      0.0   5.3
# 31   중구          동화동      217.0   27.0   82.0   1949.0  196.3      0.0   5.3
# 58   0.811278  0.360491  0.474045  0.213505 -0.253764   6.7
# 59  -0.810279 -0.093346 -0.511180 -0.114200 -0.253764   6.7
# 60   0.577180 -0.052088 -0.499610  0.274453 -0.253764   6.7
# 61   1.096763 -0.217120 -0.200572  1.195738 -0.253764   6.7
# 62   1.105328 -0.774102  1.380061 -1.074350 -0.253764   6.7
# 63   0.671390  0.195460  1.404981 -0.665381 -0.253764   6.7
# 64  -0.005210 -0.010830  1.684439 -1.077000  1.591790   6.7
# 65   0.560051 -2.857629 -0.061732  1.207221 -0.253764   6.5
# 66   1.105328 -1.042279  0.674294 -0.054135  1.591790   6.5
# 67   1.299458 -0.382152  0.193696  0.161390 -0.253764   6.5
# 68   1.145296 -0.567813  0.897683 -0.343859 -0.253764   6.5
# 69   1.913251  0.112944  0.476715  0.187890 -0.253764   6.5
# 70   2.855352  0.422378  2.678564  0.218805 -0.253764   6.5
# 71  -0.430583 -1.083537 -0.652689 -0.367708 -0.253764   6.5
# 72   1.262344 -1.289827  0.810463 -0.287327 -0.253764   6.5
# 73   1.707701 -0.093346  1.869558 -0.700713 -0.253764   6.5
# 74   0.054742 -0.629700  1.750299 -0.864124 -0.253764   6.5
# 75  -0.750327 -1.558003  1.410320 -1.604332 -0.253764   6.5
# 76   2.170188 -0.588442  1.085472 -0.041769 -0.253764   6.5
# 77   0.996843 -0.010830  1.597220 -0.571751 -0.253764   6.5
# 78  -0.436293 -0.258378  1.838408 -1.035485  1.591790   6.5
# 79   1.333716  0.051057  1.199392  0.759387 -0.253764   6.5

# %%
# VIF_data1

from statsmodels.stats.outliers_influence import variance_inflation_factor

df2 = data2.drop('저체중률', axis=1)
vif = pd.DataFrame()
vif["VIF Factor"] = [variance_inflation_factor(df2.values, i) for i in range(df2.shape[1])]
vif["features"] = df2.columns
vif
# Out:
#    VIF Factor   features
# 0    2.266373  기초생활수급자인원
# 1    1.169613      노년부양비
# 2    2.589333    고령내국인전체
# 3    1.911801      노령화지수
# 4    1.072820    무료급식소개수

# %% [markdown]
# ## >> AHP 분석

# %% [markdown]
# ### 1. 가중치 확인

# %%
# 쌍대비교행렬

li = [[1,1.333269231,1.224269231,1.320423,1.044769],
     [0.750036059,1,1.346038462,1.519192308,0.8845],
     [0.816813798,0.742920822,1,1.179385,0.878077],
     [0.757333,0.658244513,0.8479,1,0.538269],
     [0.957149,1.130582,1.138852,1.857806,1]]
col = ['기초생활수급자인원','고령자수','노인부양비','노령화지수','무료급식소개수']

ahp_df = pd.DataFrame(li, index=col, columns=col)
ahp_df
# Out:
#            기초생활수급자인원      고령자수     노인부양비     노령화지수   무료급식소개수
# 기초생활수급자인원   1.000000  1.333269  1.224269  1.320423  1.044769
# 고령자수        0.750036  1.000000  1.346038  1.519192  0.884500
# 노인부양비       0.816814  0.742921  1.000000  1.179385  0.878077
# 노령화지수       0.757333  0.658245  0.847900  1.000000  0.538269
# 무료급식소개수     0.957149  1.130582  1.138852  1.857806  1.000000

# %%
# 데이터프레임의 컬럼수 파악
colums_cnt = len(ahp_df.columns)
colums_cnt
# Out:
# 5

# %%
from scipy.stats.mstats import gmean

# 각 컬럼의 기하평균을 계산하여 리스트에 저장
geo_mean_list = []
for i in ahp_df:
    geo_mean_list.append(gmean(ahp_df[i]))
    
# 기하평균 출력
print('기하평균 (Geometric mean)\n')
for i,j in zip(ahp_df, geo_mean_list):
    print('{} : {}'.format(i, round(j,3)))  # 소수점 3 자리수
# Out:
# 기하평균 (Geometric mean)
#
# 기초생활수급자인원 : 0.85
# 고령자수 : 0.941
# 노인부양비 : 1.097
# 노령화지수 : 1.345
# 무료급식소개수 : 0.847

# %%
# 데이터프레임에 기하평균값 추가
geo = pd.DataFrame(geo_mean_list, index=col).T

ahp_df = pd.concat([ahp_df, geo], ignore_index=True)
ahp_df
# Out:
#    기초생활수급자인원      고령자수     노인부양비     노령화지수   무료급식소개수
# 0   1.000000  1.333269  1.224269  1.320423  1.044769
# 1   0.750036  1.000000  1.346038  1.519192  0.884500
# 2   0.816814  0.742921  1.000000  1.179385  0.878077
# 3   0.757333  0.658245  0.847900  1.000000  0.538269
# 4   0.957149  1.130582  1.138852  1.857806  1.000000
# 5   0.850148  0.940827  1.097360  1.344610  0.847325

# %%
# 가중치 계산을 위하여 기하평균의 합을 구함
geo_mean_sum = sum(geo_mean_list)
geo_mean_sum
# Out:
# 5.0802703696540314

# %%
# 각 컬럼의 가중치를 계산하여 리스트에 저장
weights_list = []
for i in range(colums_cnt):
    weights_list.append(geo_mean_list[i]/geo_mean_sum)
    
# 기하평균 출력
print('가중치 (Weights)\n')
for i,j in zip(ahp_df, weights_list):
    print('{} : {}'.format(i, round(j,3)))  # 소수점 3 자리수
# Out:
# 가중치 (Weights)
#
# 기초생활수급자인원 : 0.167
# 고령자수 : 0.185
# 노인부양비 : 0.216
# 노령화지수 : 0.265
# 무료급식소개수 : 0.167

# %%
# 가중치 합 확인
su_ = sum(list(weights_list))
print(round(su_,1))
# Out:
# 1.0

# %% [markdown]
# ### 2. 일관성 분석
#
# - CR < 0.1일 경우: 쌍대 비교 행렬에 합리적인 일관성이 있음.
# - 0.1 < CR < 0.2일 경우: 비일관성이 용납 가능한 수준임.
# - 0.2 < CR일 경우: 일관성이 부족해 재조사가 필요함.

# %%
bi_df = ahp_df.drop(5)
wei_df = pd.DataFrame(weights_list, index=col)

print('>> 쌍대비교행렬 \n\n{}\n'.format(bi_df))
print('>> 가중치행렬 \n{}'.format(wei_df))
# Out:
# >> 쌍대비교행렬
#
#    기초생활수급자인원      고령자수     노인부양비     노령화지수   무료급식소개수
# 0   1.000000  1.333269  1.224269  1.320423  1.044769
# 1   0.750036  1.000000  1.346038  1.519192  0.884500
# 2   0.816814  0.742921  1.000000  1.179385  0.878077
# 3   0.757333  0.658245  0.847900  1.000000  0.538269
# 4   0.957149  1.130582  1.138852  1.857806  1.000000
#
# >> 가중치행렬
#                   0
# 기초생활수급자인원  0.167343
# 고령자수       0.185192
# 노인부양비      0.216004
# 노령화지수      0.264673
# 무료급식소개수    0.166787

# %%
#1. 쌍대비교행렬과 가중치 행렬을 곱한다.

res1 = pd.DataFrame(bi_df.dot(wei_df))
print('>> Result1 \n{}'.format(res1))
# Out:
# >> Result1
#           0
# 0  1.202436
# 1  1.151068
# 2  0.948879
# 3  0.786236
# 4  1.274043

# %%
#2. 곱한 행렬의 각 값을 가중치로 나눈다.

res2 = []
for i in range(len(wei_df)):
    res2.append(res1.iloc[i,0]/wei_df.iloc[i,0])
print('>> Result2 \n{}'.format(res2))
# Out:
# >> Result2
# [7.185459679944544, 6.215527321394083, 4.3928709387664, 2.970593526114403, 7.6387231890897125]

# %%
#3. 각 값의 평균에서 요소의 개수를 빼고 요소의 개수보다 1작은 수로 나눈다.

consistency = (np.mean(res2)-5)/4
print('일관성 지수 : {}'.format(consistency))
# Out:
# 일관성 지수 : 0.17015873276545723

# %% [markdown]
#  0.17 < 0.2 이므로 비일관성이 용납 가능한 수준

# %% [markdown]
# ### 3. AHP 분석

# %%
group2_score = group2.copy()
group2_score= group2_score[['자치구','행정동']]
group2_score['점수'] = 0
group2_score['순위'] = 0
group2_score['점수'] = group2_score['점수'].astype('float')
group2_score['순위'] = group2_score['순위'].astype('int')
group2_score.head()
# Out:
#    자치구  행정동   점수  순위
# 0  종로구  사직동  0.0   0
# 1  종로구  삼청동  0.0   0
# 2  종로구  부암동  0.0   0
# 3  종로구  평창동  0.0   0
# 4  종로구  무악동  0.0   0

# %%
def score(dataframe1, dataframe2):
    for i in range(len(dataframe1)):
        dataframe1.loc[i,'점수'] = 0.167 * dataframe2.loc[i,'기초생활수급자인원'] + 0.185 * dataframe2.loc[i,'고령자수'] + 0.216 * dataframe2.loc[i,'노년부양비'] + 0.265 * dataframe2.loc[i,'노령화지수'] + 0.167 * dataframe2.loc[i,'무료급식소개수']
    dataframe1 = dataframe1.sort_values('점수', ascending=False)
    dataframe1 = dataframe1.reset_index(drop=True)
def rank(dataframe):
    for j in range(len(dataframe)):
        dataframe.loc[j,'순위'] = j+1

# %%
pd.set_option('display.max_rows', None)
score(group2_score,data2)

group2_score = group2_score.sort_values('점수', ascending=False)
group2_score.reset_index(drop=True,inplace=True)

rank(group2_score)
group2_score
# Out:
#     자치구          행정동        점수  순위
# 0   용산구          남영동  2.011026   1
# 1   성동구          마장동  1.245049   2
# 2   광진구         중곡4동  1.079217   3
# 3    중구          약수동  1.021009   4
# 4    중구         을지로동  0.866975   5
# 5   종로구         창신1동  0.718874   6
# 6   광진구         자양4동  0.614505   7
# 7    중구          회현동  0.612461   8
# 8   종로구         창신2동  0.584579   9
# 9   용산구          보광동  0.553317  10
# 10   중구          청구동  0.460521  11
# 11  광진구         중곡3동  0.439513  12
# 12   중구          중림동  0.430096  13
# 13  용산구          청파동  0.418085  14
# 14  광진구         구의2동  0.382824  15
# 15  광진구         자양1동  0.382683  16
# 16  성동구          용답동  0.373648  17
# 17   중구          다산동  0.368605  18
# 18  광진구          군자동  0.335685  19
# 19  성동구       성수2가1동  0.315248  20
# 20  용산구        용산2가동  0.299900  21
# 21  성동구          옥수동  0.288836  22
# 22  광진구         자양2동  0.265727  23
# 23  종로구  종로1.2.3.4가동  0.246166  24
# 24  광진구         자양3동  0.202860  25
# 25  성동구      금호2.3가동  0.195558  26
# 26  용산구          후암동  0.177277  27
# 27  성동구         행당2동  0.172006  28
# 28  광진구         중곡1동  0.170688  29
# 29  종로구         숭인2동  0.147405  30
# 30  광진구         중곡2동  0.101187  31
# 31  종로구      종로5.6가동  0.061850  32
# 32  용산구         이촌2동  0.054774  33
# 33   중구           명동  0.035882  34
# 34  성동구          송정동  0.023062  35
# 35  성동구        금호1가동  0.004047  36
# 36  종로구          평창동 -0.010137  37
# 37  종로구          삼청동 -0.033640  38
# 38  광진구         구의1동 -0.036376  39
# 39  용산구          한남동 -0.038422  40
# 40  종로구         숭인1동 -0.048512  41
# 41  성동구       왕십리도선동 -0.054387  42
# 42   중구          광희동 -0.057901  43
# 43  종로구          이화동 -0.063051  44
# 44   중구          신당동 -0.073537  45
# 45  광진구         구의3동 -0.074439  46
# 46  용산구          용문동 -0.117637  47
# 47   중구         신당5동 -0.148296  48
# 48  용산구         이촌1동 -0.250220  49
# 49   중구          동화동 -0.253878  50
# 50   중구           필동 -0.254812  51
# 51  성동구        금호4가동 -0.256753  52
# 52  광진구          화양동 -0.257605  53
# 53  종로구          부암동 -0.264657  54
# 54  종로구          사직동 -0.291868  55
# 55  종로구          가회동 -0.293564  56
# 56  용산구        원효로2동 -0.298834  57
# 57  용산구        이태원2동 -0.306870  58
# 58  성동구        왕십리2동 -0.311482  59
# 59  종로구         창신3동 -0.318468  60
# 60  성동구       성수2가3동 -0.322689  61
# 61  종로구        청운효자동 -0.332486  62
# 62   중구          황학동 -0.360919  63
# 63  종로구          혜화동 -0.384226  64
# 64  용산구        이태원1동 -0.393279  65
# 65  성동구          응봉동 -0.437124  66
# 66  용산구         한강로동 -0.444784  67
# 67  성동구       성수1가1동 -0.449864  68
# 68  성동구         행당1동 -0.469008  69
# 69  종로구          무악동 -0.479813  70
# 70   중구          장충동 -0.489123  71
# 71  성동구       성수1가2동 -0.504831  72
# 72  용산구         서빙고동 -0.531298  73
# 73  광진구           능동 -0.566520  74
# 74  종로구          교남동 -0.609486  75
# 75  광진구          광장동 -0.668451  76
# 76  성동구          사근동 -0.783173  77
# 77  용산구          효창동 -0.836780  78
# 78  용산구        원효로1동 -0.881604  79
# 79   중구          소공동 -1.600346  80

# %%
pd
